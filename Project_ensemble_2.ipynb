# %%
import nltk
nltk.download('inaugural')
from nltk.corpus import inaugural
inaugural.fileids()
x=inaugural.raw('1941-Roosevelt.txt')
y=inaugural.raw('1961-Kennedy.txt')
z=inaugural.raw('1973-Nixon.txt')
# Out:
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!

# %%
x_char=len(inaugural.raw('1941-Roosevelt.txt'))
y_char=len(inaugural.raw('1961-Kennedy.txt'))
z_char=len(inaugural.raw('1973-Nixon.txt'))

# %%
print('x_char',x_char)
print('y_char',y_char)
print('z_char',z_char)
# Out:
# x_char 7571
# y_char 7618
# z_char 9991

# %%
from nltk.corpus import inaugural
x_words=len(inaugural.words('1941-Roosevelt.txt'))
y_words=len(inaugural.words('1961-Kennedy.txt'))
z_words=len(inaugural.words('1973-Nixon.txt'))

# %%
print('x_words',x_words)
print('y_words',y_words)
print('z_words',z_words)
# Out:
# x_words 1536
# y_words 1546
# z_words 2028

# %%
x_sents=len(inaugural.sents('1941-Roosevelt.txt'))
y_sents=len(inaugural.sents('1961-Kennedy.txt'))
z_sents=len(inaugural.sents('1973-Nixon.txt'))

# %%
print('x_sents',x_sents)
print('y_sents',y_sents)
print('z_sents',z_sents)
# Out:
# x_sents 68
# y_sents 52
# z_sents 69

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
x
# Out:
# 'On each national day of inauguration since 1789 the people have renewed their sense of dedication to the United States\n\nIn Washingtons day the task of the people was to create and weld together a nation\n\nIn Lincolns day the task of the people was to preserve that Nation from disruption from within\n\nIn this day the task of the people is to save that Nation and its institutions from disruption from without\n\nTo us there has come a time in the midst of swift happenings to pause for a moment and take stock  to recall what our place in history has been and to rediscover what we are and what we may be If we do not we risk the real peril of inaction\n\nLives of nations are determined not by the count of years but by the lifetime of the human spirit The life of a man is threescore years and ten a little more a little less The life of a nation is the fullness of the measure of its will to live\n\nThere are men who doubt this There are men who believe that democracy as a form of Govern
# ...

# %%
x = x.translate(str.maketrans('', '', string.punctuation))
y = y.translate(str.maketrans('', '', string.punctuation))
z = z.translate(str.maketrans('', '', string.punctuation))

# %%
all_Words=x.split()
stopwords = nltk.corpus.stopwords.words('english')+list(string.punctuation)
stopwords.extend(["--", '."',"...","."])

# Converting all the words to lower casse
all_words= (x.lower() for x in all_Words)# we can skip this line since we have already converted all the words to lowercase
# Only keeping the words which are not the 'stopwords'
all_words_clean = [word for word in all_words if word not in stopwords]

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

# Create WordNetLemmatizer object
wnl = WordNetLemmatizer()

# single word lemmatization examples

for words in all_words_clean:
     wnl.lemmatize(words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.FreqDist(all_words_clean).most_common(10)
# Out:
# [('nation', 11),
#  ('know', 10),
#  ('spirit', 9),
#  ('democracy', 9),
#  ('us', 8),
#  ('life', 8),
#  ('people', 7),
#  ('america', 7),
#  ('years', 6),
#  ('freedom', 6)]

# %%
cor_x = ' '.join(all_words_clean)

# %%
cor_x
# Out:
# 'national day inauguration since 1789 people renewed sense dedication united states washingtons day task people create weld together nation lincolns day task people preserve nation disruption within day task people save nation institutions disruption without us come time midst swift happenings pause moment take stock recall place history rediscover may risk real peril inaction lives nations determined count years lifetime human spirit life man threescore years ten little little less life nation fullness measure live men doubt men believe democracy form government frame life limited measured kind mystical artificial fate unexplained reason tyranny slavery become surging wave future freedom ebbing tide americans know true eight years ago life republic seemed frozen fatalistic terror proved true midst shock acted acted quickly boldly decisively later years living years fruitful years people democracy brought us greater security hope better understanding lifes ideals measured material th
# ...

# %%
all_Words=y.split()
stopwords = nltk.corpus.stopwords.words('english')+list(string.punctuation)
stopwords.extend(["--", '."',"...","."])
# Converting all the words to lower casse
all_words = (y.lower() for y in all_Words)# we can skip this line since we have already converted all the words to lowercase
# Only keeping the words which are not the 'stopwords'
all_words_clean = [word for word in all_words if word not in stopwords]
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

# Create WordNetLemmatizer object
wnl = WordNetLemmatizer()

# single word lemmatization examples

for words in all_words_clean:
     wnl.lemmatize(words)

nltk.FreqDist(all_words_clean).most_common(50)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [('let', 16),
#  ('us', 12),
#  ('world', 8),
#  ('sides', 8),
#  ('new', 7),
#  ('pledge', 7),
#  ('citizens', 5),
#  ('power', 5),
#  ('shall', 5),
#  ('free', 5),
#  ('nations', 5),
#  ('ask', 5),
#  ('president', 4),
#  ('fellow', 4),
#  ('freedom', 4),
#  ('man', 4),
#  ('first', 4),
#  ('americans', 4),
#  ('war', 4),
#  ('peace', 4),
#  ('always', 4),
#  ('cannot', 4),
#  ('hope', 4),
#  ('help', 4),
#  ('arms', 4),
#  ('country', 4),
#  ('call', 4),
#  ('today', 3),
#  ('well', 3),
#  ('human', 3),
#  ('poverty', 3),
#  ('life', 3),
#  ('globe', 3),
#  ('dare', 3),
#  ('go', 3),
#  ('generation', 3),
#  ('know', 3),
#  ('bear', 3),
#  ('control', 3),
#  ('may', 3),
#  ('good', 3),
#  ('join', 3),
#  ('begin', 3),
#  ('never', 3),
#  ('final', 3),
#  ('vice', 2),
#  ('mr', 2),
#  ('god', 2),
#  ('forebears', 2),
#  ('century', 2)]

# %%
cor_y = ' '.join(all_words_clean)
cor_y
# Out:
# 'national day inauguration since 1789 people renewed sense dedication united states washingtons day task people create weld together nation lincolns day task people preserve nation disruption within day task people save nation institutions disruption without us come time midst swift happenings pause moment take stock recall place history rediscover may risk real peril inaction lives nations determined count years lifetime human spirit life man threescore years ten little little less life nation fullness measure live men doubt men believe democracy form government frame life limited measured kind mystical artificial fate unexplained reason tyranny slavery become surging wave future freedom ebbing tide americans know true eight years ago life republic seemed frozen fatalistic terror proved true midst shock acted acted quickly boldly decisively later years living years fruitful years people democracy brought us greater security hope better understanding lifes ideals measured material th
# ...

# %%
all_Words=z.split()
stopwords = nltk.corpus.stopwords.words('english') +list(string.punctuation)
stopwords.extend(["--", '."',"...","."])
# Converting all the words to lower casse
all_words = (z.lower() for z in all_Words)# we can skip this line since we have already converted all the words to lowercase
# Only keeping the words which are not the 'stopwords'
all_words_clean = [word for word in all_words if word not in stopwords]
wnl = WordNetLemmatizer()

# single word lemmatization examples

for words in all_words_clean:
     wnl.lemmatize(words)

nltk.FreqDist(all_words_clean).most_common(50)
# Out:
# [('us', 26),
#  ('let', 22),
#  ('peace', 19),
#  ('world', 16),
#  ('new', 15),
#  ('america', 13),
#  ('responsibility', 11),
#  ('government', 10),
#  ('great', 9),
#  ('home', 9),
#  ('abroad', 8),
#  ('nation', 8),
#  ('americas', 8),
#  ('together', 7),
#  ('years', 7),
#  ('shall', 7),
#  ('policies', 7),
#  ('role', 7),
#  ('make', 7),
#  ('every', 7),
#  ('history', 7),
#  ('better', 7),
#  ('time', 6),
#  ('nations', 6),
#  ('right', 6),
#  ('people', 6),
#  ('help', 6),
#  ('four', 5),
#  ('today', 5),
#  ('era', 5),
#  ('responsibilities', 5),
#  ('progress', 5),
#  ('come', 5),
#  ('respect', 5),
#  ('others', 5),
#  ('act', 5),
#  ('one', 5),
#  ('promise', 4),
#  ('long', 4),
#  ('work', 4),
#  ('freedom', 4),
#  ('old', 4),
#  ('proud', 4),
#  ('faith', 4),
#  ('mr', 3),
#  ('country', 3),
#  ('share', 3),
#  ('war', 3),
#  ('resolve', 3),
#  ('retreat', 3)]

# %%
cor_z = ' '.join(all_words_clean)
cor_z
# Out:
# 'mr vice president mr speaker mr chief justice senator cook mrs eisenhower fellow citizens great good country share together met four years ago america bleak spirit depressed prospect seemingly endless war abroad destructive conflict home meet today stand threshold new era peace world central question us shall use peace let us resolve era enter postwar periods often time retreat isolation leads stagnation home invites new danger abroad let us resolve become time great responsibilities greatly borne renew spirit promise america enter third century nation past year saw farreaching results new policies peace continuing revitalize traditional friendships missions peking moscow able establish base new durable pattern relationships among nations world americas bold initiatives 1972 long remembered year greatest progress since end world war ii toward lasting peace world peace seek world flimsy peace merely interlude wars peace endure generations come important understand necessity limitatio
# ...

# %%
print(len(cor_x.split()))
print(len(cor_y.split()))
print(len(cor_z.split()))
# Out:
# 627
# 693
# 833

# %%
import matplotlib.pyplot as plt
import string # this is used for string manipulations
import matplotlib

# %%
corpus_x=x.split()
corpus_y=y.split()
corpus_z=z.split()

# %%
corpus_x1 = ' '.join(corpus_x)
corpus_y1 = ' '.join(corpus_y)
corpus_z1 = ' '.join(corpus_z)

# %%
# Word Cloud
from wordcloud import WordCloud
wordcloud = WordCloud(width = 4000, height = 2000,
                      background_color ='black',
                min_font_size = 10, random_state=100).generate(cor_x)

# plot the WordCloud image
plt.figure(figsize = (6, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.xlabel('Word Cloud')
plt.tight_layout(pad = 0)

print("statement X")
plt.show()

#Tip: You can specify stopwords, regex (punctuations/symbols) in the wordcloud itself, check CTRL+TAB on the wordcloud fuction!
# Out:
# statement X

# %%
# Word Cloud
from wordcloud import WordCloud
wordcloud = WordCloud(width = 4000, height = 2000,
                      background_color ='black',
                min_font_size = 10, random_state=100).generate(cor_y)

# plot the WordCloud image
plt.figure(figsize = (6, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.xlabel('Word Cloud')
plt.tight_layout(pad = 0)

print("statement X")
plt.show()
# Out:
# statement X

# %%
# Word Cloud
from wordcloud import WordCloud
wordcloud = WordCloud(width = 4000, height = 2000,
                      background_color ='black',
                min_font_size = 10, random_state=100).generate(cor_z)

# plot the WordCloud image
plt.figure(figsize = (6, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.xlabel('Word Cloud')
plt.tight_layout(pad = 0)

print("statement X")
plt.show()
# Out:
# statement X

# %% [markdown]
# #END
